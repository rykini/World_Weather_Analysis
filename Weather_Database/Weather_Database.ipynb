# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | yar-sale
# Processing Record 3 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | flinders
# Processing Record 6 of Set 1 | chapais
# Processing Record 7 of Set 1 | coihaique
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | bathsheba
# Processing Record 10 of Set 1 | danilov
# Processing Record 11 of Set 1 | neryungri
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | rockport
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | axixa do tocantins
# City not found. Skipping...
# Processing Record 18 of Set 1 | constitucion
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | vila franca do campo
# Processing Record 26 of Set 1 | sao miguel do araguaia
# Processing Record 27 of Set 1 | teya
# Processing Record 28 of Set 1 | sur
# Processing Record 29 of Set 1 | krasnoarmeysk
# Processing Record 30 of Set 1 | cabedelo
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | valdosta
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | tautira
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | leningradskiy
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | shimsk
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | namibe
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | pangnirtung
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | bure
# Processing Record 4 of Set 2 | lianzhou
# Processing Record 5 of Set 2 | talnakh
# Processing Record 6 of Set 2 | altamira
# Processing Record 7 of Set 2 | green river
# Processing Record 8 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | batagay-alyta
# Processing Record 11 of Set 2 | pella
# Processing Record 12 of Set 2 | mancora
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | lodja
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | padang
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | linares
# Processing Record 19 of Set 2 | zhanaozen
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | oneonta
# Processing Record 22 of Set 2 | lazaro cardenas
# Processing Record 23 of Set 2 | egvekinot
# Processing Record 24 of Set 2 | belle fourche
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | saint george
# Processing Record 27 of Set 2 | nanortalik
# Processing Record 28 of Set 2 | sakakah
# Processing Record 29 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 2 | cabo san lucas
# Processing Record 31 of Set 2 | olafsvik
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | vila
# Processing Record 34 of Set 2 | baruun-urt
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | kudahuvadhoo
# Processing Record 37 of Set 2 | iralaya
# Processing Record 38 of Set 2 | binga
# Processing Record 39 of Set 2 | makakilo city
# Processing Record 40 of Set 2 | esperance
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | dhidhdhoo
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | tanete
# Processing Record 45 of Set 2 | alice springs
# Processing Record 46 of Set 2 | tiruvottiyur
# City not found. Skipping...
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | bagdarin
# Processing Record 2 of Set 3 | pidhorodne
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | taoudenni
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | rafraf
# Processing Record 8 of Set 3 | husavik
# Processing Record 9 of Set 3 | nuuk
# Processing Record 10 of Set 3 | nome
# Processing Record 11 of Set 3 | port hardy
# Processing Record 12 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 14 of Set 3 | moron
# Processing Record 15 of Set 3 | tasiilaq
# Processing Record 16 of Set 3 | jati
# Processing Record 17 of Set 3 | sao joao da barra
# Processing Record 18 of Set 3 | luba
# Processing Record 19 of Set 3 | geraldton
# Processing Record 20 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 3 | kusu
# Processing Record 23 of Set 3 | lucea
# Processing Record 24 of Set 3 | coquimbo
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 27 of Set 3 | middelburg
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | shingu
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | oranjestad
# Processing Record 32 of Set 3 | sitka
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | gazojak
# Processing Record 35 of Set 3 | merrill
# Processing Record 36 of Set 3 | amherst center
# Processing Record 37 of Set 3 | thano bula khan
# City not found. Skipping...
# Processing Record 38 of Set 3 | bataipora
# Processing Record 39 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 3 | chuy
# Processing Record 41 of Set 3 | nevelsk
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | morgan city
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | vanavara
# Processing Record 46 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 47 of Set 3 | belaya gora
# Processing Record 48 of Set 3 | zhigansk
# Processing Record 49 of Set 3 | mount gambier
# Processing Record 50 of Set 3 | bongor
# Processing Record 1 of Set 4 | katsuura
# Processing Record 2 of Set 4 | varhaug
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | assai
# Processing Record 5 of Set 4 | nhulunbuy
# Processing Record 6 of Set 4 | comodoro rivadavia
# Processing Record 7 of Set 4 | berbera
# Processing Record 8 of Set 4 | marsaxlokk
# Processing Record 9 of Set 4 | anloga
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | kishi
# Processing Record 12 of Set 4 | pa sang
# Processing Record 13 of Set 4 | port-gentil
# Processing Record 14 of Set 4 | rivadavia
# Processing Record 15 of Set 4 | jimma
# Processing Record 16 of Set 4 | aklavik
# Processing Record 17 of Set 4 | gisors
# Processing Record 18 of Set 4 | kahului
# Processing Record 19 of Set 4 | freeport
# Processing Record 20 of Set 4 | jamestown
# Processing Record 21 of Set 4 | arraial do cabo
# Processing Record 22 of Set 4 | hofn
# Processing Record 23 of Set 4 | arlit
# Processing Record 24 of Set 4 | port keats
# Processing Record 25 of Set 4 | trinidad
# Processing Record 26 of Set 4 | redlands
# Processing Record 27 of Set 4 | pevek
# Processing Record 28 of Set 4 | inuvik
# Processing Record 29 of Set 4 | hualmay
# Processing Record 30 of Set 4 | saint-philippe
# Processing Record 31 of Set 4 | evensk
# Processing Record 32 of Set 4 | ahipara
# Processing Record 33 of Set 4 | santiago del estero
# Processing Record 34 of Set 4 | upernavik
# Processing Record 35 of Set 4 | carrollton
# Processing Record 36 of Set 4 | saldanha
# Processing Record 37 of Set 4 | la ronge
# Processing Record 38 of Set 4 | mnogovershinnyy
# Processing Record 39 of Set 4 | rantepao
# Processing Record 40 of Set 4 | port blair
# Processing Record 41 of Set 4 | port elizabeth
# Processing Record 42 of Set 4 | pangai
# Processing Record 43 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 4 | kavaratti
# Processing Record 45 of Set 4 | ostrovnoy
# Processing Record 46 of Set 4 | victoria
# Processing Record 47 of Set 4 | kizema
# Processing Record 48 of Set 4 | loukhi
# Processing Record 49 of Set 4 | yerbogachen
# Processing Record 50 of Set 4 | mehamn
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | rapid valley
# Processing Record 4 of Set 5 | verkhniy uslon
# Processing Record 5 of Set 5 | raghunathpur
# Processing Record 6 of Set 5 | dalian
# Processing Record 7 of Set 5 | avera
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | san patricio
# Processing Record 10 of Set 5 | nizwa
# Processing Record 11 of Set 5 | barrow
# Processing Record 12 of Set 5 | cap malheureux
# Processing Record 13 of Set 5 | alabaster
# Processing Record 14 of Set 5 | sirsa
# Processing Record 15 of Set 5 | verkhnyaya inta
# Processing Record 16 of Set 5 | lac du bonnet
# Processing Record 17 of Set 5 | marsa matruh
# Processing Record 18 of Set 5 | maxixe
# Processing Record 19 of Set 5 | tanabe
# Processing Record 20 of Set 5 | lata
# Processing Record 21 of Set 5 | praya
# Processing Record 22 of Set 5 | mount isa
# Processing Record 23 of Set 5 | port hedland
# Processing Record 24 of Set 5 | san carlos de bariloche
# Processing Record 25 of Set 5 | sheksna
# Processing Record 26 of Set 5 | mecca
# Processing Record 27 of Set 5 | aksu
# Processing Record 28 of Set 5 | hilo
# Processing Record 29 of Set 5 | maine-soroa
# Processing Record 30 of Set 5 | katsina
# Processing Record 31 of Set 5 | ilulissat
# Processing Record 32 of Set 5 | ecully
# Processing Record 33 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 5 | caravelas
# Processing Record 35 of Set 5 | cherskiy
# Processing Record 36 of Set 5 | barcelos
# Processing Record 37 of Set 5 | saint-francois
# Processing Record 38 of Set 5 | shenjiamen
# Processing Record 39 of Set 5 | tallahassee
# Processing Record 40 of Set 5 | chaman
# Processing Record 41 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 5 | half moon bay
# Processing Record 43 of Set 5 | necochea
# Processing Record 44 of Set 5 | san rafael
# Processing Record 45 of Set 5 | los llanos de aridane
# Processing Record 46 of Set 5 | qinggang
# Processing Record 47 of Set 5 | komsomolskiy
# Processing Record 48 of Set 5 | burnie
# Processing Record 49 of Set 5 | kununurra
# Processing Record 50 of Set 5 | san jeronimo
# Processing Record 1 of Set 6 | jinka
# Processing Record 2 of Set 6 | lebu
# Processing Record 3 of Set 6 | ponta do sol
# Processing Record 4 of Set 6 | castro
# Processing Record 5 of Set 6 | dahuk
# Processing Record 6 of Set 6 | dillon
# Processing Record 7 of Set 6 | xiangxiang
# Processing Record 8 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | hurghada
# Processing Record 11 of Set 6 | abu samrah
# Processing Record 12 of Set 6 | yeppoon
# Processing Record 13 of Set 6 | malindi
# Processing Record 14 of Set 6 | lethem
# Processing Record 15 of Set 6 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 16 of Set 6 | candido de abreu
# Processing Record 17 of Set 6 | the valley
# Processing Record 18 of Set 6 | abakaliki
# Processing Record 19 of Set 6 | la roche-sur-yon
# Processing Record 20 of Set 6 | kampot
# Processing Record 21 of Set 6 | chokurdakh
# Processing Record 22 of Set 6 | umm bab
# Processing Record 23 of Set 6 | sohag
# Processing Record 24 of Set 6 | mitu
# Processing Record 25 of Set 6 | campo verde
# Processing Record 26 of Set 6 | kamenka
# Processing Record 27 of Set 6 | salym
# Processing Record 28 of Set 6 | salinopolis
# Processing Record 29 of Set 6 | sisimiut
# Processing Record 30 of Set 6 | bara
# Processing Record 31 of Set 6 | xiongyue
# Processing Record 32 of Set 6 | bethel
# Processing Record 33 of Set 6 | tselinnoye
# Processing Record 34 of Set 6 | ballina
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | quebo
# Processing Record 37 of Set 6 | mahon
# Processing Record 38 of Set 6 | lucapa
# Processing Record 39 of Set 6 | gizo
# Processing Record 40 of Set 6 | hervey bay
# Processing Record 41 of Set 6 | sorland
# Processing Record 42 of Set 6 | ramhormoz
# Processing Record 43 of Set 6 | tilichiki
# Processing Record 44 of Set 6 | jiexiu
# Processing Record 45 of Set 6 | prince rupert
# Processing Record 46 of Set 6 | carlisle
# Processing Record 47 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 6 | monte carmelo
# Processing Record 49 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 7 | sinnamary
# Processing Record 3 of Set 7 | saint-pierre
# Processing Record 4 of Set 7 | darhan
# Processing Record 5 of Set 7 | esmeraldas
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | kamyshla
# Processing Record 8 of Set 7 | heiligenhafen
# Processing Record 9 of Set 7 | saskylakh
# Processing Record 10 of Set 7 | florence
# Processing Record 11 of Set 7 | beringovskiy
# Processing Record 12 of Set 7 | chake chake
# Processing Record 13 of Set 7 | samarai
# Processing Record 14 of Set 7 | ancud
# Processing Record 15 of Set 7 | fare
# Processing Record 16 of Set 7 | berlevag
# Processing Record 17 of Set 7 | largo
# Processing Record 18 of Set 7 | kainantu
# Processing Record 19 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 20 of Set 7 | lima
# Processing Record 21 of Set 7 | snasa
# Processing Record 22 of Set 7 | serebryansk
# Processing Record 23 of Set 7 | marsh harbour
# Processing Record 24 of Set 7 | kazachinskoye
# Processing Record 25 of Set 7 | havre-saint-pierre
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | parsabad
# Processing Record 28 of Set 7 | neuquen
# Processing Record 29 of Set 7 | beloha
# Processing Record 30 of Set 7 | bilibino
# Processing Record 31 of Set 7 | pathein
# Processing Record 32 of Set 7 | coahuayana
# Processing Record 33 of Set 7 | ajaccio
# Processing Record 34 of Set 7 | witu
# Processing Record 35 of Set 7 | minsk
# Processing Record 36 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 7 | moissala
# Processing Record 38 of Set 7 | faanui
# Processing Record 39 of Set 7 | antofagasta
# Processing Record 40 of Set 7 | bintulu
# Processing Record 41 of Set 7 | tessalit
# Processing Record 42 of Set 7 | puro
# Processing Record 43 of Set 7 | rawson
# Processing Record 44 of Set 7 | camacha
# Processing Record 45 of Set 7 | khorinsk
# Processing Record 46 of Set 7 | ye
# City not found. Skipping...
# Processing Record 47 of Set 7 | kavieng
# Processing Record 48 of Set 7 | nyurba
# Processing Record 49 of Set 7 | tillabery
# City not found. Skipping...
# Processing Record 50 of Set 7 | sept-iles
# Processing Record 1 of Set 8 | willowmore
# Processing Record 2 of Set 8 | hami
# Processing Record 3 of Set 8 | sayyan
# Processing Record 4 of Set 8 | kuminskiy
# Processing Record 5 of Set 8 | college
# Processing Record 6 of Set 8 | gainesville
# Processing Record 7 of Set 8 | ola
# Processing Record 8 of Set 8 | yulara
# Processing Record 9 of Set 8 | nantucket
# Processing Record 10 of Set 8 | tual
# Processing Record 11 of Set 8 | evanston
# Processing Record 12 of Set 8 | khasan
# Processing Record 13 of Set 8 | airai
# Processing Record 14 of Set 8 | charters towers
# Processing Record 15 of Set 8 | tuatapere
# Processing Record 16 of Set 8 | ilhabela
# Processing Record 17 of Set 8 | mogadishu
# Processing Record 18 of Set 8 | lavrentiya
# Processing Record 19 of Set 8 | kolimvari
# City not found. Skipping...
# Processing Record 20 of Set 8 | kamina
# Processing Record 21 of Set 8 | adrar
# Processing Record 22 of Set 8 | sharan
# Processing Record 23 of Set 8 | lumphat
# Processing Record 24 of Set 8 | harboore
# Processing Record 25 of Set 8 | eydhafushi
# Processing Record 26 of Set 8 | byron bay
# Processing Record 27 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 8 | cranendonck
# Processing Record 29 of Set 8 | niles
# Processing Record 30 of Set 8 | mariveles
# Processing Record 31 of Set 8 | mareeba
# Processing Record 32 of Set 8 | kulachi
# Processing Record 33 of Set 8 | san luis
# Processing Record 34 of Set 8 | uhlove
# Processing Record 35 of Set 8 | camana
# Processing Record 36 of Set 8 | fairbanks
# Processing Record 37 of Set 8 | saint-augustin
# Processing Record 38 of Set 8 | nikolayevsk-na-amure
# Processing Record 39 of Set 8 | twin falls
# Processing Record 40 of Set 8 | kemijarvi
# Processing Record 41 of Set 8 | wajir
# Processing Record 42 of Set 8 | huilong
# Processing Record 43 of Set 8 | uruzgan
# Processing Record 44 of Set 8 | yuzhno-kurilsk
# Processing Record 45 of Set 8 | catamarca
# Processing Record 46 of Set 8 | lerwick
# Processing Record 47 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 8 | te anau
# Processing Record 49 of Set 8 | bismarck
# Processing Record 50 of Set 8 | brebes
# Processing Record 1 of Set 9 | puerto escondido
# Processing Record 2 of Set 9 | jiamusi
# Processing Record 3 of Set 9 | westport
# Processing Record 4 of Set 9 | najran
# Processing Record 5 of Set 9 | nouadhibou
# Processing Record 6 of Set 9 | port arthur
# Processing Record 7 of Set 9 | takaka
# Processing Record 8 of Set 9 | lima duarte
# Processing Record 9 of Set 9 | suntar
# Processing Record 10 of Set 9 | tocopilla
# Processing Record 11 of Set 9 | fortuna
# Processing Record 12 of Set 9 | codrington
# Processing Record 13 of Set 9 | concordia
# Processing Record 14 of Set 9 | dunedin
# Processing Record 15 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 9 | nalgonda
# Processing Record 17 of Set 9 | touros
# Processing Record 18 of Set 9 | gushikawa
# Processing Record 19 of Set 9 | kailua
# Processing Record 20 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 9 | vestmanna
# Processing Record 22 of Set 9 | palmer
# Processing Record 23 of Set 9 | bandarbeyla
# Processing Record 24 of Set 9 | santo antonio do ica
# Processing Record 25 of Set 9 | narsaq
# Processing Record 26 of Set 9 | bodden town
# Processing Record 27 of Set 9 | aitape
# Processing Record 28 of Set 9 | lorengau
# Processing Record 29 of Set 9 | pisco
# Processing Record 30 of Set 9 | altay
# Processing Record 31 of Set 9 | moussoro
# Processing Record 32 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 33 of Set 9 | itarema
# Processing Record 34 of Set 9 | lufilufi
# Processing Record 35 of Set 9 | zarand
# Processing Record 36 of Set 9 | tura
# Processing Record 37 of Set 9 | rudbar
# Processing Record 38 of Set 9 | angra dos reis
# Processing Record 39 of Set 9 | bela vista de goias
# Processing Record 40 of Set 9 | igarka
# Processing Record 41 of Set 9 | numan
# Processing Record 42 of Set 9 | qandala
# Processing Record 43 of Set 9 | paita
# Processing Record 44 of Set 9 | nelson bay
# Processing Record 45 of Set 9 | vancouver
# Processing Record 46 of Set 9 | killybegs
# Processing Record 47 of Set 9 | teguise
# Processing Record 48 of Set 9 | puerto quijarro
# Processing Record 49 of Set 9 | madang
# Processing Record 50 of Set 9 | yumen
# Processing Record 1 of Set 10 | garoua boulai
# Processing Record 2 of Set 10 | batagay
# Processing Record 3 of Set 10 | kamen-rybolov
# Processing Record 4 of Set 10 | viedma
# Processing Record 5 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 10 | aripuana
# Processing Record 7 of Set 10 | alofi
# Processing Record 8 of Set 10 | maloyaz
# City not found. Skipping...
# Processing Record 9 of Set 10 | bairiki
# Processing Record 10 of Set 10 | aguimes
# Processing Record 11 of Set 10 | carutapera
# Processing Record 12 of Set 10 | hasaki
# Processing Record 13 of Set 10 | hammerfest
# Processing Record 14 of Set 10 | alta floresta
# Processing Record 15 of Set 10 | ilfracombe
# Processing Record 16 of Set 10 | puerto leguizamo
# Processing Record 17 of Set 10 | biak
# Processing Record 18 of Set 10 | honiara
# Processing Record 19 of Set 10 | loanda
# Processing Record 20 of Set 10 | gorontalo
# Processing Record 21 of Set 10 | tikamgarh
# Processing Record 22 of Set 10 | enshi
# Processing Record 23 of Set 10 | oranjemund
# Processing Record 24 of Set 10 | ketchikan
# Processing Record 25 of Set 10 | kyra
# Processing Record 26 of Set 10 | acarau
# Processing Record 27 of Set 10 | hurricane
# Processing Record 28 of Set 10 | am timan
# Processing Record 29 of Set 10 | sioux lookout
# Processing Record 30 of Set 10 | raudeberg
# Processing Record 31 of Set 10 | pak phanang
# Processing Record 32 of Set 10 | barranco
# Processing Record 33 of Set 10 | inirida
# Processing Record 34 of Set 10 | port augusta
# Processing Record 35 of Set 10 | steinbach
# Processing Record 36 of Set 10 | presidencia roque saenz pena
# Processing Record 37 of Set 10 | ugoofaaru
# Processing Record 38 of Set 10 | chicama
# Processing Record 39 of Set 10 | asfi
# Processing Record 40 of Set 10 | galesong
# Processing Record 41 of Set 10 | halifax
# Processing Record 42 of Set 10 | honggang
# Processing Record 43 of Set 10 | puerto madryn
# Processing Record 44 of Set 10 | tsaratanana
# Processing Record 45 of Set 10 | taltal
# Processing Record 46 of Set 10 | vestmannaeyjar
# Processing Record 47 of Set 10 | palaikastron
# Processing Record 48 of Set 10 | kadubivtsi
# Processing Record 49 of Set 10 | ayr
# Processing Record 50 of Set 10 | guntakal
# Processing Record 1 of Set 11 | chigasaki
# Processing Record 2 of Set 11 | richards bay
# Processing Record 3 of Set 11 | hoi an
# Processing Record 4 of Set 11 | kalemie
# Processing Record 5 of Set 11 | isangel
# Processing Record 6 of Set 11 | barranca
# Processing Record 7 of Set 11 | iskateley
# Processing Record 8 of Set 11 | hay river
# Processing Record 9 of Set 11 | polyarnyy
# Processing Record 10 of Set 11 | kuala selangor
# Processing Record 11 of Set 11 | urumqi
# Processing Record 12 of Set 11 | tambura
# Processing Record 13 of Set 11 | arona
# Processing Record 14 of Set 11 | yingcheng
# Processing Record 15 of Set 11 | vallenar
# Processing Record 16 of Set 11 | okha
# Processing Record 17 of Set 11 | khulo
# Processing Record 18 of Set 11 | lakatoro
# Processing Record 19 of Set 11 | benghazi
# Processing Record 20 of Set 11 | amapa
# Processing Record 21 of Set 11 | rengo
# Processing Record 22 of Set 11 | boundiali
# Processing Record 23 of Set 11 | ust-tsilma
# Processing Record 24 of Set 11 | wangqing
# Processing Record 25 of Set 11 | jardim
# Processing Record 26 of Set 11 | kasongo-lunda
# Processing Record 27 of Set 11 | aginskoye
# Processing Record 28 of Set 11 | rebrikha
# Processing Record 29 of Set 11 | ulaangom
# Processing Record 30 of Set 11 | hamilton
# Processing Record 31 of Set 11 | dondo
# Processing Record 32 of Set 11 | arman
# Processing Record 33 of Set 11 | colares
# Processing Record 34 of Set 11 | lompoc
# Processing Record 35 of Set 11 | merauke
# Processing Record 36 of Set 11 | keuruu
# Processing Record 37 of Set 11 | mizdah
# Processing Record 38 of Set 11 | kalevala
# Processing Record 39 of Set 11 | chau doc
# Processing Record 40 of Set 11 | edea
# Processing Record 41 of Set 11 | mana
# Processing Record 42 of Set 11 | scarborough
# Processing Record 43 of Set 11 | vila velha
# Processing Record 44 of Set 11 | vilyuysk
# Processing Record 45 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 11 | nagua
# Processing Record 47 of Set 11 | naze
# Processing Record 48 of Set 11 | olinda
# Processing Record 49 of Set 11 | bilimbay
# Processing Record 50 of Set 11 | erenhot
# Processing Record 1 of Set 12 | jalu
# Processing Record 2 of Set 12 | bela
# Processing Record 3 of Set 12 | gamba
# Processing Record 4 of Set 12 | vao
# Processing Record 5 of Set 12 | aliquippa
# Processing Record 6 of Set 12 | wanning
# Processing Record 7 of Set 12 | penzance
# Processing Record 8 of Set 12 | aswan
# Processing Record 9 of Set 12 | kedrovyy
# Processing Record 10 of Set 12 | petropolis
# Processing Record 11 of Set 12 | kalmunai
# Processing Record 12 of Set 12 | villazon
# Processing Record 13 of Set 12 | sibolga
# Processing Record 14 of Set 12 | macamic
# Processing Record 15 of Set 12 | kaspiyskiy
# Processing Record 16 of Set 12 | porterville
# Processing Record 17 of Set 12 | jiaocheng
# Processing Record 18 of Set 12 | tlacotepec
# Processing Record 19 of Set 12 | regina
# Processing Record 20 of Set 12 | miranda
# Processing Record 21 of Set 12 | dengfeng
# Processing Record 22 of Set 12 | pontianak
# Processing Record 23 of Set 12 | tomigusuku
# Processing Record 24 of Set 12 | ndele
# Processing Record 25 of Set 12 | turukhansk
# Processing Record 26 of Set 12 | rio gallegos
# Processing Record 27 of Set 12 | umm lajj
# Processing Record 28 of Set 12 | brunswick
# Processing Record 29 of Set 12 | alferrarede
# Processing Record 30 of Set 12 | lekoni
# Processing Record 31 of Set 12 | polunochnoye
# Processing Record 32 of Set 12 | tomatlan
# Processing Record 33 of Set 12 | blonduos
# City not found. Skipping...
# Processing Record 34 of Set 12 | korsakov
# Processing Record 35 of Set 12 | gurupa
# Processing Record 36 of Set 12 | sapouy
# Processing Record 37 of Set 12 | san cristobal
# Processing Record 38 of Set 12 | batesville
# Processing Record 39 of Set 12 | dingle
# Processing Record 40 of Set 12 | rabaul
# Processing Record 41 of Set 12 | lyuban
# Processing Record 42 of Set 12 | conde
# Processing Record 43 of Set 12 | nizhniy bestyakh
# Processing Record 44 of Set 12 | bukama
# Processing Record 45 of Set 12 | fort nelson
# Processing Record 46 of Set 12 | khor
# Processing Record 47 of Set 12 | lagoa
# Processing Record 48 of Set 12 | thinadhoo
# Processing Record 49 of Set 12 | okakarara
# Processing Record 50 of Set 12 | manado
# Processing Record 1 of Set 13 | northam
# Processing Record 2 of Set 13 | juntas
# Processing Record 3 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 13 | slavonice
# Processing Record 5 of Set 13 | rock sound
# Processing Record 6 of Set 13 | champerico
# Processing Record 7 of Set 13 | chiliile
# Processing Record 8 of Set 13 | soe
# Processing Record 9 of Set 13 | anadyr
# Processing Record 10 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 11 of Set 13 | marzuq
# Processing Record 12 of Set 13 | tucupita
# Processing Record 13 of Set 13 | springfield
# Processing Record 14 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 16 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 13 | nykoping
# Processing Record 18 of Set 13 | zhanakorgan
# Processing Record 19 of Set 13 | yenotayevka
# Processing Record 20 of Set 13 | siuna
# Processing Record 21 of Set 13 | doka
# Processing Record 22 of Set 13 | santa maria
# Processing Record 23 of Set 13 | tabuk
# Processing Record 24 of Set 13 | nemuro
# Processing Record 25 of Set 13 | phitsanulok
# Processing Record 26 of Set 13 | vreed en hoop
# City not found. Skipping...
# Processing Record 27 of Set 13 | srednekolymsk
# Processing Record 28 of Set 13 | basarabeasca
# Processing Record 29 of Set 13 | cap-aux-meules
# Processing Record 30 of Set 13 | kralendijk
# Processing Record 31 of Set 13 | oyek
# Processing Record 32 of Set 13 | buje
# Processing Record 33 of Set 13 | nizhniy kuranakh
# Processing Record 34 of Set 13 | cayenne
# Processing Record 35 of Set 13 | ciudad bolivar
# Processing Record 36 of Set 13 | callaway
# Processing Record 37 of Set 13 | maltahohe
# Processing Record 38 of Set 13 | sovetskiy
# Processing Record 39 of Set 13 | opuwo
# Processing Record 40 of Set 13 | strezhevoy
# Processing Record 41 of Set 13 | karratha
# Processing Record 42 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 13 | tiarei
# Processing Record 44 of Set 13 | swan hill
# Processing Record 45 of Set 13 | port macquarie
# Processing Record 46 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 13 | osoyoos
# Processing Record 48 of Set 13 | paris
# Processing Record 49 of Set 13 | mayumba
# Processing Record 50 of Set 13 | sabang
# Processing Record 1 of Set 14 | kuytun
# Processing Record 2 of Set 14 | lakota
# Processing Record 3 of Set 14 | labuhan
# Processing Record 4 of Set 14 | copiapo
# Processing Record 5 of Set 14 | macheng
# Processing Record 6 of Set 14 | qasigiannguit
# Processing Record 7 of Set 14 | ponta delgada
# Processing Record 8 of Set 14 | villa carlos paz
# Processing Record 9 of Set 14 | pacific grove
# Processing Record 10 of Set 14 | portland
# Processing Record 11 of Set 14 | kaeo
# Processing Record 12 of Set 14 | haileybury
# Processing Record 13 of Set 14 | grand gaube
# Processing Record 14 of Set 14 | san quintin
# Processing Record 15 of Set 14 | luderitz
# Processing Record 16 of Set 14 | tome
# Processing Record 17 of Set 14 | altamont
# Processing Record 18 of Set 14 | phon thong
# Processing Record 19 of Set 14 | stornoway
# Processing Record 20 of Set 14 | calama
# Processing Record 21 of Set 14 | asau
# Processing Record 22 of Set 14 | houma
# Processing Record 23 of Set 14 | porbandar
# Processing Record 24 of Set 14 | la solana
# Processing Record 25 of Set 14 | arawa
# Processing Record 26 of Set 14 | wuwei
# Processing Record 27 of Set 14 | lamar
# Processing Record 28 of Set 14 | marawi
# Processing Record 29 of Set 14 | poya
# Processing Record 30 of Set 14 | boffa
# Processing Record 31 of Set 14 | kautokeino
# Processing Record 32 of Set 14 | seaforth
# Processing Record 33 of Set 14 | vangaindrano
# Processing Record 34 of Set 14 | ilinskiy
# Processing Record 35 of Set 14 | nyakahanga
# Processing Record 36 of Set 14 | manica
# Processing Record 37 of Set 14 | san juan de opoa
# Processing Record 38 of Set 14 | ibra
# Processing Record 39 of Set 14 | dakar
# Processing Record 40 of Set 14 | huntsville
# Processing Record 41 of Set 14 | shelburne
# Processing Record 42 of Set 14 | margate
# Processing Record 43 of Set 14 | hobyo
# Processing Record 44 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 45 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 14 | kuandian
# Processing Record 47 of Set 14 | mkushi
# Processing Record 48 of Set 14 | ferkessedougou
# Processing Record 49 of Set 14 | celarevo
# Processing Record 50 of Set 14 | simbahan
# Processing Record 1 of Set 15 | nayoro
# Processing Record 2 of Set 15 | alcamo
# Processing Record 3 of Set 15 | agadez
# Processing Record 4 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 15 | mackay
# Processing Record 6 of Set 15 | walvis bay
# Processing Record 7 of Set 15 | umm kaddadah
# Processing Record 8 of Set 15 | narrabri
# Processing Record 9 of Set 15 | poum
# Processing Record 10 of Set 15 | hoquiam
# Processing Record 11 of Set 15 | les cayes
# Processing Record 12 of Set 15 | lagos
# Processing Record 13 of Set 15 | republic
# Processing Record 14 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 15 of Set 15 | port-cartier
# Processing Record 16 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 17 of Set 15 | blackwater
# Processing Record 18 of Set 15 | la rioja
# Processing Record 19 of Set 15 | hirado
# Processing Record 20 of Set 15 | fallon
# Processing Record 21 of Set 15 | itaituba
# Processing Record 22 of Set 15 | brigham city
# Processing Record 23 of Set 15 | kropotkin
# Processing Record 24 of Set 15 | ningxiang
# Processing Record 25 of Set 15 | verkhniy baskunchak
# Processing Record 26 of Set 15 | narowal
# Processing Record 27 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 15 | al
# City not found. Skipping...
# Processing Record 29 of Set 15 | ulladulla
# Processing Record 30 of Set 15 | manggar
# Processing Record 31 of Set 15 | sisophon
# Processing Record 32 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 15 | roald
# Processing Record 35 of Set 15 | west wendover
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Khatanga      RU  71.9667  102.5000     17.46        85          98
# 1     Yar-Sale      RU  66.8333   70.8333     30.96        98         100
# 2  Tuktoyaktuk      CA  69.4541 -133.0374     -9.40        70           1
# 3     Flinders      AU -34.5833  150.8552     50.00        50           6
# 4      Chapais      CA  49.7834  -74.8492     59.00        29          75
# 5    Coihaique      CL -45.5752  -72.0662     60.80        67          75
# 6      Ushuaia      AR -54.8000  -68.3000     50.00        53          75
# 7    Bathsheba      BB  13.2167  -59.5167     80.60        65          20
# 8      Danilov      RU  58.1908   40.1717     36.52        96          61
# 9    Neryungri      RU  56.6709  124.6491    -11.43        98          87
#
#    Wind Speed Current Description
# 0       12.75     overcast clouds
# 1       15.77          light snow
# 2       10.36           clear sky
# 3       12.66           clear sky
# 4       12.66       broken clouds
# 5       14.97          light rain
# 6       19.57       broken clouds
# 7       13.80        volcanic ash
# 8        2.68       broken clouds
# 9        3.60     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
